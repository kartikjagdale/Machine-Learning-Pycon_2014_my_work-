# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(normalize=True)
print model.normalize
# Out:
# True

# %%
print model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=True)

# %%
x = np.array([0,1,2 ])
y = np.array([0,1,2])
x
y
# Out:
# array([0, 1, 2])

# %%
plt.plot(x,y,marker='o');

# %%
X = x[:, np.newaxis] #conevrt 1D to 2D
X
# Out:
# array([[0],
#        [1],
#        [2]])

# %%
model.fit(X,y)
model.coef_
# Out:
# array([ 1.00000003])

# %% [markdown]
# ## Supervised Learning: Classification and regression

# %% [markdown]
# Supervised learning is further broken down into two categories, classification and regression

# %% [markdown]
# ### Classification
# K nearest neighbors (kNN) is one of the simplest learning strategies: given a new, unknown observation, look up in your reference database which ones have the closest features and assign the predominant class.
#
# Let's try it out on our iris classification problem:

# %%
from sklearn import neighbors, datasets
iris = datasets.load_iris()
X, y = iris.data, iris.target
knn = neighbors.KNeighborsClassifier(n_neighbors=1)
knn.fit(X, y)

print iris.target_names[knn.predict([3,5,4,2])]
# Out:
# ['virginica']

# %%
from fig_code import plot_iris_classification
plot_iris_classification(neighbors.KNeighborsClassifier, n_neighbors=1)

# %% [markdown]
# ##Excercise

# %%
from sklearn.svm import SVC
u_iris = [[3,5,4,2]]
#using SVC to train and preidct the species of the unkown iris
svm = SVC()
svm.fit(X, y)

print iris.target_names[svm.predict(u_iris)]
# Out:
# ['virginica']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-895fd1ba5c0b> in <module>()
#       6
#       7 print iris.target_names[svm.predict(u_iris)]
# ----> 8 print iris.target_names[svm.predict_proba(u_iris)]
#
# C:\Python27\lib\site-packages\sklearn\svm\base.pyc in predict_proba(self)
#     505         datasets.
#     506         """
# --> 507         self._check_proba()
#     508         return self._predict_proba
#     509
#
# C:\Python27\lib\site-packages\sklearn\svm\base.pyc in _check_proba(self)
#     475         if not self.probability:
#     476             raise AttributeError("predict_proba is not available when"
# --> 477                                  " probability=%r" % self.probability)
#     478         if self._impl not in ('c_svc', 'nu_svc'):
#     479             raise AttributeError("predict_proba only implemented for SVC"
#
# ...

# %%
from fig_code import plot_iris_classification
plot_iris_classification(neighbors.KNeighborsClassifier, n_neighbors=1)

# %% [markdown]
# ##Unsupeevised Learning

# %% [markdown]
# ###Dimensionality  Reduction

# %%
X, y = iris.data, iris.target
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
X_reduced = pca.transform(X)
print X.shape
print "Reduced dataset shape:", X_reduced.shape
# Out:
# (150, 4)
# Reduced dataset shape: (150, 2)

# %%
plt.scatter(X_reduced[:, 0],X_reduced[:, 1], c=y);

# %%
print "Meaning of the 2 Components: "
for component in pca.components_:
    print " + ".join("%.2f x %s" % (value, name)
    for value, name in zip(component, iris.feature_names))
# Out:
# Meaning of the 2 Components:
# 0.36 x sepal length (cm) + -0.08 x sepal width (cm) + 0.86 x petal length (cm) + 0.36 x petal width (cm)
# -0.66 x sepal length (cm) + -0.73 x sepal width (cm) + 0.18 x petal length (cm) + 0.07 x petal width (cm)

# %% [markdown]
# ###Clustering

# %% [markdown]
# ####Kmeans

# %%
from sklearn.cluster import KMeans
k_means = KMeans(n_clusters=3, random_state=0)
k_means.fit(X)
y_pred = k_means.predict(X)
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y_pred);

# %%
#PCA?
